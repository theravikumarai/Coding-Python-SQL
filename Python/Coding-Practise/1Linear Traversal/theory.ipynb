# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Examples:
#
#     for num in numbers:
#         ...
#
#     or
#
#     for ch in string:
#         ...
#
#     or
#
#     for i in range(len(arr)):
#     ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Template
#
#     Most problems follow this structure:
#
#     def solve(arr):
#
#         # Step 1: Initialize
#         result = ...
#
#         # Step 2: Traverse
#         for item in arr:
#
#             # Step 3: Process
#             ...
#
#         # Step 4: Return
#         return result

# %% [markdown]
# # Common Operations

# %% [markdown]
# # Counting
#
#     count = 0
#
#     for x in arr:
#         if condition:
#             count +=1
#
#     Examples:
#
#         Count vowels
#         Count even numbers
#         Count positives
#         Count uppercase letters

# %% [markdown]
# ## Sum
#
#     total = 0
#
#     for x in arr:
#         total +=x
#
#     Examples:
#
#     Sum of array
#     Sum of even numbers
#     Sum of digits

# %% [markdown]
# ## Maximum
#     maximum = arr[0]
#
#     for x in arr:
#         if x > maximum:
#             maximum = x

# %% [markdown]
# ## Minimum
#     minimum = arr[0]
#
#     for x in arr:
#         if x < minimum:
#             minimum = x

# %% [markdown]
# ## Searching
#     for x in arr:
#         if x == target:
#             return True
#
#     return False

# %% [markdown]
# ## Updating Result
#
#     result = []
#
#     for x in arr:
#         if condition:
#             result.append(x)
#
#     Examples:
#
#     Extract vowels
#     Extract even numbers
#     Filter positives

# %% [markdown]
# # Complexity
#
#     If there are n elements:
#
#     Time: O(n)
#     Space: O(1) (if no extra collection is created)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
